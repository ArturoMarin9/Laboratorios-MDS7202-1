# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2024</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Sebastián Tinoco
# - Auxiliar: Catherine Benavides
# - Ayudante: Nicolás Ojeda, Eduardo Moya

# %% [markdown]
# ### Equipo: Los Galácticos
#
# - Nombre de alumno 1: Arturo Marín
# - Nombre de alumno 2: Martín González

# %% [markdown]
# ### **Link de repositorio de GitHub:** https://github.com/ArturoMarin9/Laboratorios-MDS7202-1

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 7 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos Y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquer material del curso que estimen conveniente.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 1. Git es un sistema de control de versiones distribuido que permite a los usuarios registrar cambios en archivos a lo largo del tiempo. Cada usuario tiene una copia completa del repositorio en su dispositivo, lo que facilita el trabajo colaborativo en paralelo. Con Git, se pueden ver instantáneas antiguas del proyecto, revisar los cambios realizados con sus respectivas descripciones, y sincronizar los cambios entre usuarios a través de un servidor remoto. Esto proporciona un historial completo del desarrollo del proyecto y facilita la gestión efectiva del trabajo en equipo.
#
# 2.
# * Git es el sistema de control de versiones distribuido que permite a los usuarios gestionar el historial de cambios de un proyecto localmente.GitHub, por otro lado, es una plataforma en línea que permite a los usuarios alojar, colaborar y gestionar proyectos utilizando Git. Proporciona características adicionales como seguimiento de problemas, solicitudes de extracción, integración continua, entre otros.
#
#
# * Git es un proyecto de código abierto desarrollado por Linus Torvalds y otros colaboradores. Cualquiera puede descargar, usar y contribuir al desarrollo de Git de forma gratuita.
# GitHub, por otro lado, es una empresa que ofrece servicios basados en la nube para alojar proyectos Git en línea. Aunque GitHub ofrece planes gratuitos, también tiene opciones de suscripción para características avanzadas y soporte adicional.
#
# * Git se ejecuta en la máquina local del usuario y gestiona el control de versiones de los proyectos almacenados en ese sistema. GitHub proporciona un servidor remoto donde se pueden alojar repositorios Git, permitiendo a los usuarios colaborar en proyectos de forma remota, realizar seguimiento de problemas, revisar código y realizar otras operaciones relacionadas con el desarrollo de software en
#
# 3. En Git, un hash es como un número de serie único para cada objeto, generado por un algoritmo especial. Por ejemplo, un commit podría tener un hash como "f1a2b3c4d5e6". Este hash es como una huella digital digital que identifica el contenido y los detalles del commit de manera única. Es esencial para seguir y administrar cambios en un repositorio Git, ya que proporciona una forma precisa de referenciar cada estado del proyecto a lo largo del tiempo. Sin él, sería difícil navegar por el historial de cambios y mantener el control sobre el desarrollo del proyecto.
#
# 4. La estructura de datos de Git se compone de varios elementos esenciales que facilitan la gestión y el seguimiento de los cambios en un repositorio. En primer lugar, están los objetos, que representan los datos almacenados en el repositorio, como archivos, directorios, commits y etiquetas. Luego, las referencias (refs) actúan como punteros que apuntan a objetos específicos en el historial del repositorio, como ramas, etiquetas y HEAD. HEAD es una referencia especial que indica el commit actualmente seleccionado y la rama en la que se está trabajando. Además, el index, también conocido como staging area, sirve como un área intermedia donde se preparan los cambios antes de confirmarlos en un commit. Estos componentes forman la base de la estructura de datos de Git, permitiendo una gestión eficiente de versiones y colaboración en proyectos de desarrollo de software.
#
#
# 5.
# * Agregar archivos al staging area: `git add directorio_del_archivo` (o `git add` . para agregar todos los archivos del directorio actual).
# * Confirmar cambios: `git commit -m "Comentario descriptivo del commit"`.
# * Revisar el estado del repositorio: `git status`.
# * Revisar las diferencias entre el último commit y el workspace actual: `git diff`.
# * Revisar el registro de commits: `git log`.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 6. Falso. Git no siempre resuelve automáticamente los problemas de líneas al hacer merge entre diferentes ramas. Puede ocurrir un conflicto si hay cambios conflictivos en las mismas líneas de archivos entre las ramas fusionadas. En este caso, Git solicitará al usuario que resuelva manualmente los conflictos.
#
# 7. Falso. Ejecutar `git pull` sobre un repositorio no es equivalente a ejecutar `git clone`. `git pull` se utiliza para recuperar cambios del repositorio remoto y fusionarlos con la rama actual, mientras que `git clone` se utiliza para clonar un repositorio remoto y crear una copia local del mismo.
#
# 8. Falso. `git status` y `git log` generan resultados diferentes en Git. `git status` muestra el estado actual del directorio de trabajo y los archivos que han sido modificados o están en el área de preparación, mientras que `git log` muestra un registro de commits realizados en el repositorio.
#
# 9. Verdadero. En Git, es posible deshacer cambios y volver a versiones anteriores del código utilizando varios comandos, como `git reset`, `git checkout`, o incluso revertir commits específicos. Estas herramientas permiten deshacer cambios no deseados o volver a una versión anterior del código.
#
# 10. Falso. El comando `git commit` se utiliza para confirmar los cambios en el repositorio local, pero no para enviar cambios al repositorio remoto. Para enviar cambios al repositorio remoto, se utiliza el comando `git push`.

# %% [markdown]
# Por último, investigue y comente para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
#
# `git stash` se utiliza en Git para almacenar temporalmente los cambios locales que no se desean confirmar de inmediato en un commit. Git stash guarda los cambios en un área temporal llamada "stash" y limpia el directorio de trabajo para que esté limpio. Esto es útil cuando se está trabajando en una tarea y surge la necesidad de cambiar de contexto temporalmente sin necesidad de realizar un commit. Luego, los cambios almacenados en el stash se pueden recuperar más tarde utilizando otros comandos, como git stash apply o git stash pop.
#
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)
#
# `git reset` se utiliza en Git para cambiar la posición del HEAD y opcionalmente modificar el índice (área de preparación) y el directorio de trabajo. Puede usarse para deshacer cambios en el directorio de trabajo y el índice, mover el HEAD a un commit específico o incluso deshacer commits. La diferencia principal entre git reset y git revert radica en su efecto en el historial de commits. git reset modifica el historial de commits, eliminando commits o moviendo ramas a commits específicos, mientras que git revert crea un nuevo commit que deshace los cambios introducidos por un commit previo, sin alterar el historial de commits existente. En resumen, git reset se utiliza para manipular el historial de commits, mientras que git revert se utiliza para deshacer cambios sin modificar el historial de commits.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto? "git clone ..."
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code> https://github.com/ArturoMarin9
#
# <code>Link Presentacion 2:</code> https://github.com/martingzz

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code> git clone https://github.com/MDS7202/lab1.git

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>

# %% [markdown]
# El archivo .gitignore contiene:
#  videos/
# *.txt
# !texts/171.txt

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code> El tema general del proyecto son los animales, y se divide en 2 partes, por un lado están los animales normales y por otro los animales animados. En el repositorio clonado desde github se tienen 2 archivos .py, los cuales tienen como objetivo definir una función y crear un programa para emular el sonido de animales.
#
# Por otro lado, está la carpeta descargada desde U-Cursos, en donde se presentan 2 carpetas, una llamada "texts", que contiene archivos de textos con fragmentos del guión de Shrek 2 (una pelicula donde algunos personajes son animales animados), y otra llamada "videos", que contiene un video de una adaptación del animé Akira con personajes animados del programa 31 Minutos, estos también corresponden a animales animados.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# Se utilizó: git log --all --graph --decorate
#
# Se observan 4 commit, cada uno lleva (además del autor, la fecha y las ramas asociadas a la acción) un comentario indicando que fue lo que se realizó, por lo cual si son informativos.
#
# - Comentario commit 1: "primer commit" -> No indica las ramas asociadas a este.
# - Comentario commit 2: "se agrega función" -> Aquí podría indicarse a grandes rasgos que función se agregó, además no se indican las ramas asociadas a este.
# - Comentario commit 3: "Se separa el proyecto en módulos".
# - Comentario 4: "fix ifs" -> Aquí podría explicitarse el archivo o la parte del código en donde se hace.

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# El error en el código está en el archivo animales.py, específicamente en la función animales(input). El problema radica en el uso de múltiples declaraciones if independientes en lugar de usar elif o else para controlar el flujo del programa.
#
# Esto radica en un problema porque todas las declaraciones if se evalúan de forma independiente, lo que significa que cada una de ellas se verifica incluso si la condición anterior ya se cumplió. Lo mencionado puede provocar que múltiples mensajes se impriman o que se levante una excepción de valor "ValueError..." incorrectamente.
#
# Utilizando el comando "git blame animales.py" identificamos a mezosky como el usuario que cometió dicho error.

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# Para comenzar, los 3 commit fueron realizados por distintos usuarios y en distintos momentos.
#
# Por otro lado, hay diferencias en las ramas y en los identificadores de estos. Por ejemplo, el último commit pertenece a la rama origin/fix-ifs, mientras que el segundo commit está en la rama main y también tiene referencias a otras ramas (origin/new_features, origin/main, origin/HEAD). El primer commit no muestra ninguna referencia a la rama en la que se encuentra.

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# Para realizar el merge se utilizó el siguiente código:
#
# git checkout main #Para asegurarse que estemos en la rama main
#
# git merge origin/fix-ifs #Hacemos el merge con la rama solicitada
#
# Aparece el siguiente mensaje -> "CONFLICT (content): Merge conflict in main.py
# Automatic merge failed; fix conflicts and then commit the result."
#
# Dicho mensaje estaría indicando que existe un conflicto de fusión en el archivo main.py.
#
# Esto estaría ocurriendo en la parte donde se importa la función animales desde el archivo animales.py. La rama main tiene el import del archivo animales.py, mientras que la rama fix-ifs tiene la definición de la función animales directamente en el archivo main.py. Esto indica que ambas ramas han modificado la misma sección del archivo, lo que resultó en un conflicto de fusión.

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# A continuación se muestran los pasos que se siguieron para solucionar el problema anterior:
# - Paso 1: "Creación de una nueva rama"
#
#   Creamos una rama nueva desde el estado actual de 'main', llamada 'fix-merge-conflict', mediante el siguiente código:
#
#   git checkout -b fix-merge-conflict
#
# - Paso 2: Resolvemos manualmente el conflicto en main.py
#
#   Dejamos el código del archivo de la siguiente forma (eliminando la definición de 'animales' del archivo main.py):
#
#   from animales import animales
#
#   if __name__ == '__main__':
#
#     print("Ingrese el animalito para saber que dice:")
#
#     animal = input()
#
#     animales(animal)
#
# - Paso 3: Agregamos los cambios y hacemos commit
#
#   Ya con el conflicto resulto, guardamos los cambios en main.py y los agregamos al área de preparación, para posteriormente realizar el commit:
#
#   git add main.py
#
#   git commit -m "Resolución de conflicto de fusión"
#
# - Paso 4: Completamos la fusión de la rama 'fix-ifs' con la rama 'main':
#
#   git checkout main
#
#   git merge fix-merge-conflict
#
# - Paso 5: Eliminamos la rama temporal creada para solucionar el conflicto:
#
#   git branch -d fix-merge-conflict

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
